# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\smc\anaconda3\lib\site-packages (1.8.2)
# Requirement already satisfied: black>=24.10.0 in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (25.12.0)
# Requirement already satisfied: bleach in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: kagglesdk in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (0.1.13)
# Requirement already satisfied: mypy>=1.15.0 in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: protobuf in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (4.25.3)
# Requirement already satisfied: python-dateutil in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (75.1.0)
# Requirement already satisfied: six>=1.10 in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (4.66.5)
# Requirement already satisfied: types-requests in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\smc\anaconda3\lib\site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\smc\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\smc\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\smc\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (24.1)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\smc\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\smc\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (3.10.0)
# Requirement already satisfied: pytokens>=0.3.0 in c:\users\smc\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (0.3.0)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\smc\anaconda3\lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in c:\users\smc\anaconda3\lib\site-packages (from mypy>=1.15.0->kaggle) (0.7.4)
# Requirement already satisfied: webencodings in c:\users\smc\anaconda3\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\smc\anaconda3\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\smc\anaconda3\lib\site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\smc\anaconda3\lib\site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smc\anaconda3\lib\site-packages (from requests->kaggle) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\smc\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)

# %%
import kaggle

# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# Downloading orders.csv.zip to D:\CDE\Data Analytics Project
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 272kB/s]
# 100%|##########| 200k/200k [00:00<00:00, 272kB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('orders.csv.zip')
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd

df = pd.read_csv('orders.csv', na_values=['Not Available', 'unknown'])
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
#
#    discount_percent
# 0                 2
# 1                 3
# 2                 5
# 3                 2
# 4                 5

# %%
df['discount']=df['list_price']*df['discount_percent']*.01
df['sale_price']=df['list_price']-df['discount']
df['profit']=df['sale_price']-df['cost_price']

df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
#
#    discount_percent  discount  sale_price  profit
# 0                 2       5.2       254.8    14.8
# 1                 3      21.9       708.1   108.1
# 2                 5       0.5         9.5    -0.5
# 3                 2      19.2       940.8   160.8
# 4                 5       1.0        19.0    -1.0

# %%
df["order_date"] = pd.to_datetime(df["order_date"], format="%Y-%m-%d")

# %%
df.drop(columns=["cost_price","list_price","discount_percent"],inplace=True)

# %%
df.head(5)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount  sale_price  profit
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# 1       Chairs  FUR-CH-10000454         3      21.9       708.1   108.1
# 2       Labels  OFF-LA-10000240         2       0.5         9.5    -0.5
# 3       Tables  FUR-TA-10000577         5      19.2       940.8   160.8
# 4      Storage  OFF-ST-10000760         2       1.0        19.0    -1.0

# %%
import sqlalchemy as sal
engine = sal.create_engine('mssql://DESKTOP-6HRT637/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn=engine.connect()

# %%
df.to_sql('df_orders', con=conn , index=False, if_exists = 'append')
# Out:
# 38
